# %% [markdown]
# <a href="https://colab.research.google.com/github/deand21/WEEK-3/blob/main/week_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ===================================================
# Nama     : Deand Timothy Immanuel S               =
# NIM      : 4232501028                             =
# Mata Kuliah : Pemrograman Dasar                   =
# Pertemuan : 3                                     =
# ===================================================


#B.1 SOAL UMUM

#NO 1

bilangan1 = 5
bilangan2 = 6

print("Hasil penjumlahan :", bilangan1 + bilangan2)
print("Hasil pengurangan :", bilangan1 - bilangan2)
print("Hasil perkalian   :", bilangan1 * bilangan2)
print("Hasil pembagian   :", bilangan1 / bilangan2)
print("Hasil pembagian bulat :", bilangan1 // bilangan2)
print("Hasil modulus     :", bilangan1 % bilangan2)
# Out:
# Hasil penjumlahan : 11
# Hasil pengurangan : -1
# Hasil perkalian   : 30
# Hasil pembagian   : 0.8333333333333334
# Hasil pembagian bulat : 0
# Hasil modulus     : 5

# %%
# ===================================================
# Nama     : Deand Timothy Immanuel S               =
# NIM      : 4232501028                             =
# Mata Kuliah : Pemrograman Dasar                   =
# Pertemuan : 3                                     =
# ===================================================

# NO 2

nilai = 72

lulus = nilai >= 60

print("Nilai ini termasuk kategori lulus (>= 60):", lulus)
# Out:
# Nilai ini termasuk kategori lulus (>= 60): True

# %%
# ===================================================
# Nama     : Deand Timothy Immanuel S               =
# NIM      : 4232501028                             =
# Mata Kuliah : Pemrograman Dasar                   =
# Pertemuan : 3                                     =
# ===================================================

# NO 3

umur = 20
sim = ("Apakah memiliki SIM? (True/False): ")

punya_sim = sim = "True"

boleh_mengemudi = (umur >= 17) and punya_sim

print ("Boleh mengemudi sendiri :", boleh_mengemudi)
# Out:
# Boleh mengemudi sendiri : True

# %%
# ===================================================
# Nama     : Deand Timothy Immanuel S               =
# NIM      : 4232501028                             =
# Mata Kuliah : Pemrograman Dasar                   =
# Pertemuan : 3                                     =
# ===================================================

#B.2 SOAL KONTEKS ENERGI

#NO 4

energi_input = 35
energi_output = 5

efisiensi = (energi_output / energi_input) * 100

print(f"Efisiensi termal unit pembangkit adalah {efisiensi:.2f}%")
# Out:
# Efisiensi termal unit pembangkit adalah 14.29%

# %%
# ===================================================
# Nama     : Deand Timothy Immanuel S               =
# NIM      : 4232501028                             =
# Mata Kuliah : Pemrograman Dasar                   =
# Pertemuan : 3                                     =
# ===================================================

#NO 5

suhu_boiler = 551
beban = 99

perlu_maintenance = (suhu_boiler > 550) or (beban > 95)

print(f"Status unit pembangkit: perlu maintenance = {perlu_maintenance}")
# Out:
# Status unit pembangkit: perlu maintenance = True
